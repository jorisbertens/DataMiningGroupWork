# %%
import sqlite3
import pandas as pd
# source: https://docs.python.org/3/library/sqlite3.html

my_path = 'insurance.db'

#dbname = "datamining.db"

# connect to the database
conn = sqlite3.connect(my_path)

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-b80e42d2330d> in <module>()
# ----> 1 cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
#       2 print(cursor.fetchall())
#
# NameError: name 'cursor' is not defined

# %%
#Making a query that marge all tables in data base insurance 

query_Merge = "SELECT * from LOB L inner join Engage E on E.'Customer Identity'=L.'Customer Identity';"
query_LOB = "SELECT * from LOB;"
query_Engage = "SELECT * from Engage;"

#Split tables in order to explore each one by one

df_LOB= pd.read_sql_query(query_LOB,conn)
df_Engage = pd.read_sql_query(query_Engage,conn)
df_Merge= pd.read_sql_query(query_Merge,conn)

# %%
#Exploring values of table LOB
df_LOB.describe()
# Out:
#              index  Customer Identity  Premiums in LOB: Motor  \
# count  10296.00000        10296.00000            10262.000000
# mean    5147.50000         5148.50000              300.470252
# std     2972.34352         2972.34352              211.914997
# min        0.00000            1.00000               -4.110000
# 25%     2573.75000         2574.75000              190.590000
# 50%     5147.50000         5148.50000              298.610000
# 75%     7721.25000         7722.25000              408.300000
# max    10295.00000        10296.00000            11604.420000
#
#        Premiums in LOB: Household  Premiums in LOB: Health  \
# count                10296.000000             10253.000000
# mean                   210.431192               171.580833
# std                    352.595984               296.405976
# min                    -75.000000                -2.110000
# 25%                     49.450000               111.800000
# ...

# %%
#Counting null values table LOB

df_LOB.isnull().sum(axis=0)
# Out:
# index                                    0
# Customer Identity                        0
# Premiums in LOB: Motor                  34
# Premiums in LOB: Household               0
# Premiums in LOB: Health                 43
# Premiums in LOB:  Life                 104
# Premiums in LOB: Work Compensations     86
# dtype: int64

# %%
#Exploring values of table Engage
df_Engage.describe()
# Out:
#              index  Customer Identity  First Policy´s Year  Brithday Year  \
# count  10296.00000        10296.00000         10266.000000   10279.000000
# mean    5147.50000         5148.50000          1991.062634    1968.007783
# std     2972.34352         2972.34352           511.267913      19.709476
# min        0.00000            1.00000          1974.000000    1028.000000
# 25%     2573.75000         2574.75000          1980.000000    1953.000000
# 50%     5147.50000         5148.50000          1986.000000    1968.000000
# 75%     7721.25000         7722.25000          1992.000000    1983.000000
# max    10295.00000        10296.00000         53784.000000    2001.000000
#
#        Gross Monthly Salary  Geographic Living Area  Has Children (Y=1)  \
# count          10260.000000            10295.000000        10275.000000
# mean            2506.667057                2.709859            0.706764
# std             1157.449634                1.266291            0.455268
# ...

# %%
#Counting null values table Engage

df_Engage.isnull().sum(axis=0)
# Out:
# index                       0
# Customer Identity           0
# First Policy´s Year        30
# Brithday Year              17
# Educational Degree         17
# Gross Monthly Salary       36
# Geographic Living Area      1
# Has Children (Y=1)         21
# Customer Monetary Value     0
# Claims Rate                 0
# dtype: int64

# %%
df_Merge.describe()
# Out:
#              index  Customer Identity  Premiums in LOB: Motor  \
# count  10296.00000        10296.00000            10262.000000
# mean    5147.50000         5148.50000              300.470252
# std     2972.34352         2972.34352              211.914997
# min        0.00000            1.00000               -4.110000
# 25%     2573.75000         2574.75000              190.590000
# 50%     5147.50000         5148.50000              298.610000
# 75%     7721.25000         7722.25000              408.300000
# max    10295.00000        10296.00000            11604.420000
#
#        Premiums in LOB: Household  Premiums in LOB: Health  \
# count                10296.000000             10253.000000
# mean                   210.431192               171.580833
# std                    352.595984               296.405976
# min                    -75.000000                -2.110000
# 25%                     49.450000               111.800000
# ...

# %%
#Show data on my merge table

df_Merge.count()
# Out:
# index                                  10296
# Customer Identity                      10296
# Premiums in LOB: Motor                 10262
# Premiums in LOB: Household             10296
# Premiums in LOB: Health                10253
# Premiums in LOB:  Life                 10192
# Premiums in LOB: Work Compensations    10210
# index                                  10296
# Customer Identity                      10296
# First Policy´s Year                    10266
# Brithday Year                          10279
# Educational Degree                     10279
# Gross Monthly Salary                   10260
# Geographic Living Area                 10295
# Has Children (Y=1)                     10275
# Customer Monetary Value                10296
# Claims Rate                            10296
# dtype: int64

# %%
# Out:
#              index  Customer Identity  Premiums in LOB: Motor  \
# count  10296.00000        10296.00000            10262.000000
# mean    5147.50000         5148.50000              300.470252
# std     2972.34352         2972.34352              211.914997
# min        0.00000            1.00000               -4.110000
# 25%     2573.75000         2574.75000              190.590000
# 50%     5147.50000         5148.50000              298.610000
# 75%     7721.25000         7722.25000              408.300000
# max    10295.00000        10296.00000            11604.420000
#
#        Premiums in LOB: Household  Premiums in LOB: Health  \
# count                10296.000000             10253.000000
# mean                   210.431192               171.580833
# std                    352.595984               296.405976
# min                    -75.000000                -2.110000
# 25%                     49.450000               111.800000
# ...

# %%
corr=df_Merge.corr(method='pearson')

corr.iloc[2:,2:]
# Out:
#                                      Premiums in LOB: Motor  \
# Premiums in LOB: Motor                             1.000000
# Premiums in LOB: Household                        -0.276720
# Premiums in LOB: Health                           -0.077721
# Premiums in LOB:  Life                            -0.409424
# Premiums in LOB: Work Compensations               -0.350368
# index                                             -0.005235
# Customer Identity                                 -0.005235
# First Policy´s Year                                0.002314
# Brithday Year                                     -0.157014
# Gross Monthly Salary                               0.135842
# Geographic Living Area                             0.000737
# Has Children (Y=1)                                 0.155954
# Customer Monetary Value                            0.033655
# Claims Rate                                       -0.006459
#
# ...

# %%
df_Merge["Has Children (Y=1)"].value_counts()
# Out:
# 1.0    7262
# 0.0    3013
# Name: Has Children (Y=1), dtype: int64

# %%
df_Merge["First Policy´s Year"].value_counts()
# Out:
# 1988.0     512
# 1994.0     475
# 1993.0     473
# 1989.0     466
# 1984.0     464
# 1986.0     458
# 1978.0     453
# 1977.0     453
# 1992.0     451
# 1990.0     449
# 1995.0     445
# 1981.0     445
# 1982.0     444
# 1979.0     443
# 1996.0     440
# 1987.0     438
# 1976.0     433
# 1980.0     432
# 1991.0     430
# 1985.0     429
# 1983.0     423
# 1975.0     285
# 1997.0     271
# 1974.0     141
# 1998.0     112
# 53784.0      1
# Name: First Policy´s Year, dtype: int64

# %%
# missing data and data error example year 1028

df_Merge["Brithday Year"].value_counts()
# Out:
# 1962.0    206
# 1968.0    200
# 1964.0    194
# 1953.0    193
# 1981.0    190
# 1990.0    189
# 1974.0    187
# 1951.0    186
# 1963.0    186
# 1952.0    186
# 1954.0    185
# 1977.0    185
# 1984.0    185
# 1946.0    182
# 1949.0    179
# 1967.0    179
# 1994.0    177
# 1986.0    177
# 1975.0    176
# 1956.0    174
# 1957.0    173
# 1978.0    173
# 1955.0    172
# 1958.0    171
# 1959.0    171
# 1947.0    171
# 1980.0    170
# 1970.0    170
# 1944.0    170
# 1989.0    170
#          ...
# 1992.0    163
# 1943.0    163
# 1973.0    163
# 1942.0    162
# 1988.0    162
# 1965.0    160
# 1991.0    159
# 1985.0    158
# 1983.0    157
# 1993.0    155
# 1961.0    155
# 1995.0    155
# 1971.0    150
# 1950.0    150
# 1941.0    145
# 1972.0    143
# 1996.0    137
# 1997.0    133
# 1969.0    130
# 1940.0    127
# 1939.0    101
# 1998.0     94
# 1938.0     77
# 1999.0     69
# 1937.0     57
# 1936.0     37
# 2000.0     35
# 1935.0     14
# 2001.0     12
# 1028.0      1
# ...

# %%
df_Merge[].value_counts()
# Out:
#   File "<ipython-input-73-0843aa9d865e>", line 1
#     df_Merge[].value_counts()
#              ^
# SyntaxError: invalid syntax

# %%
# Ask to the profesor if is correct that first policy year could be greater then birthday year is 

Policy_val= df_Merge["First Policy´s Year"]-df_Merge["Brithday Year"]

df_Merge[Policy_val<=0]
# Out:
#        index  Customer Identity  Premiums in LOB: Motor  \
# 1          1                  2                   77.46
# 13        13                 14                   44.34
# 18        18                 19                  313.17
# 20        20                 21                  329.84
# 22        22                 23                  209.04
# 40        40                 41                   52.01
# 44        44                 45                  111.80
# 46        46                 47                  269.94
# 71        71                 72                  150.03
# 95        95                 96                  296.50
# 105      105                106                   89.24
# 108      108                109                   79.68
# 134      134                135                  490.98
# 142      142                143                  213.04
# 145      145                146                  144.36
# 149      149                150                   64.90
# ...
